# %%
# !pip install bs4
# !pip install requests

import requests
from bs4 import BeautifulSoup as bs


r = requests.get("https://wikileaks.org/clinton-emails/?q=%28favor+%26+confidential%29+%7C+%28favor+%26+classified%29&mfrom=&mto=&title=&notitle=&date_from=&date_to=&nofrom=&noto=&count=50&sort=0&page=1&#searchresult")

soup = bs(r.content)

print(soup.prettify())
